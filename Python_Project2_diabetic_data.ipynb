# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv')

# %% [markdown]
# An exploration of diabetes data
#
# **The Task**
#
# -the goal of this project is to analyze diabetes data
#
# -pick any group in this dataset as an initial comparison point
#
# -pick a feature/measure/indicator
#
# **Compare** above group to any other (different) group - you only
# need to do one additional group comparison (but you’re welcome to
# do more comparisons if you feel compelled to do so)
#
# -the analysis should include some descriptive statistics
#
# -the analysis should include one cleaning task (or more)
#
# -the analysis should include one visualization (or more)
#
# -the analysis should include a brief conclusion statement (not more

# %%
#To understand the dataset
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
#To understand the dataset
df.tail()
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 101761                  1                         3                    7
# 101762                  1                         4                    5
# 101763                  1                         1                    7
# 101764                  2                         3                    7
# 101765                  1                         1                    7
#
#         time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
#To understand the dataset
df.shape
# Out:
# (101766, 50)

# %%
#To understand the dataset
df.count()
# Out:
# encounter_id                101766
# patient_nbr                 101766
# race                        101766
# gender                      101766
# age                         101766
# weight                      101766
# admission_type_id           101766
# discharge_disposition_id    101766
# admission_source_id         101766
# time_in_hospital            101766
# payer_code                  101766
# medical_specialty           101766
# num_lab_procedures          101766
# num_procedures              101766
# num_medications             101766
# number_outpatient           101766
# number_emergency            101766
# number_inpatient            101766
# diag_1                      101766
# diag_2                      101766
# diag_3                      101766
# number_diagnoses            101766
# max_glu_serum               101766
# A1Cresult                   101766
# metformin                   101766
# repaglinide                 101766
# nateglinide                 101766
# ...

# %%
#To understand the dataset
print(df.dtypes)
# Out:
# encounter_id                 int64
# patient_nbr                  int64
# race                        object
# gender                      object
# age                         object
# weight                      object
# admission_type_id            int64
# discharge_disposition_id     int64
# admission_source_id          int64
# time_in_hospital             int64
# payer_code                  object
# medical_specialty           object
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# metformin                   object
# repaglinide                 object
# nateglinide                 object
# ...

# %%
#To obtain the summary statistics of the dataset
df.describe()
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  1.017660e+05  1.017660e+05      101766.000000
# mean   1.652016e+08  5.433040e+07           2.024006
# std    1.026403e+08  3.869636e+07           1.445403
# min    1.252200e+04  1.350000e+02           1.000000
# 25%    8.496119e+07  2.341322e+07           1.000000
# 50%    1.523890e+08  4.550514e+07           1.000000
# 75%    2.302709e+08  8.754595e+07           3.000000
# max    4.438672e+08  1.895026e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# ...

# %%
#To eliminate duplicates that might exist in the dataset
df.drop_duplicates()
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)      ?
# 1             149190     55629189        Caucasian  Female  [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3             500364     82442376        Caucasian    Male  [30-40)      ?
# 4              16680     42519267        Caucasian    Male  [40-50)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
# ...

# %%
#To drop the '?' values in the race column and to verify the effectiveness of this cleaning operation
df_new=df.drop(df[df['race']=='?'].index)
df_new.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
#To verify the effectiveness of the dropping operation
df_new.tail()
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 101761                  1                         3                    7
# 101762                  1                         4                    5
# 101763                  1                         1                    7
# 101764                  2                         3                    7
# 101765                  1                         1                    7
#
#         time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
#To verify the effectiveness of the dropping operation
df_new.shape
# Out:
# (99493, 50)

# %%
#To filter the dataset and create a subset of seven columns necessary for the analysis
df2 = df_new[['encounter_id','patient_nbr','race','gender','age','time_in_hospital','diabetesMed']]
df2.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age  \
# 0       2278392      8222157        Caucasian  Female   [0-10)
# 1        149190     55629189        Caucasian  Female  [10-20)
# 2         64410     86047875  AfricanAmerican  Female  [20-30)
# 3        500364     82442376        Caucasian    Male  [30-40)
# 4         16680     42519267        Caucasian    Male  [40-50)
#
#    time_in_hospital diabetesMed
# 0                 1          No
# 1                 3         Yes
# 2                 2         Yes
# 3                 2         Yes
# 4                 1         Yes

# %%
#To calculate, applying the groupby function, the number of hospitalizations per race
df2.groupby(['race'])['encounter_id'].count().sort_values(ascending=False)
# Out:
# race
# Caucasian          76099
# AfricanAmerican    19210
# Hispanic            2037
# Other               1506
# Asian                641
# Name: encounter_id, dtype: int64

# %%
#To visualize the result of the above operation
color = (0.2, # redness
         0.4, # greenness
         0.2, # blueness
         0.6 # transparency
         )

df2.groupby(['race'])['encounter_id'].count().sort_values(ascending=False).plot(kind='bar',color=color)
plt.title('Comparison of hospitalizations number due to diabetes with regard to race')
# Out:
# Text(0.5, 1.0, 'Comparison of hospitalizations number due to diabetes with regard to race')

# %%
#A pie chart for the same above result
df2.groupby(['race'])['encounter_id'].count().sort_values(ascending=False).plot(kind='pie')
plt.title('Comparison of hospitalizations number due to diabetes with regard to race')
# Out:
# Text(0.5, 1.0, 'Comparison of hospitalizations number due to diabetes with regard to race')

# %%
#To calculate, applying the groupby function, the number of hospitalizations per gender
df2.groupby(['gender'])['encounter_id'].count().sort_values(ascending=False)
# Out:
# gender
# Female             53575
# Male               45917
# Unknown/Invalid        1
# Name: encounter_id, dtype: int64

# %%
#
color=['red','blue']

df2.groupby(['gender'])['encounter_id'].count().sort_values(ascending=False).plot(kind='bar',color=color)
plt.title('Comparison of hospitalizations number due to diabetes with regard to gender')
# Out:
# Text(0.5, 1.0, 'Comparison of hospitalizations number due to diabetes with regard to gender')

# %%
#To calculate, applying the groupby function, the number of hospitalizations per age
df2.groupby(['age'])['encounter_id'].count().sort_values(ascending=False)
# Out:
# age
# [70-80)     25469
# [60-70)     21988
# [50-60)     16895
# [80-90)     16800
# [40-50)      9465
# [30-40)      3699
# [90-100)     2724
# [20-30)      1611
# [10-20)       682
# [0-10)        160
# Name: encounter_id, dtype: int64

# %%
#To visualize the result of the above operation
color=['orange','blue']

df2.groupby(['age'])['encounter_id'].count().sort_values(ascending=False).plot(kind='bar',figsize=(10,6),color=color)
plt.title('Comparison of hospitalizations number due to diabetes with regard to age')
# Out:
# Text(0.5, 1.0, 'Comparison of hospitalizations number due to diabetes with regard to age')

# %%
#To calculate, applying the groupby function, the average time, in days, spent by a patient at the hospital, per age
df2.groupby(['race',])['time_in_hospital'].mean().sort_values(ascending=False)
# Out:
# race
# AfricanAmerican    4.507860
# Caucasian          4.385721
# Other              4.273572
# Hispanic           4.059892
# Asian              3.995320
# Name: time_in_hospital, dtype: float64

# %%
#To visualize the reesult of the above operation
color=['red','orange','blue','lightblue','green']


df2.groupby(['race',])['time_in_hospital'].mean().sort_values(ascending=False).plot(kind='bar',figsize=(8,4),color=color)
plt.title('Average time in days spent in hospital due to diabetes by race')
# Out:
# Text(0.5, 1.0, 'Average time in days spent in hospital due to diabetes by race')

# %%
#To calculate, applying the groupby function, the average time, in days, spent by a patient at the hospital, per gender
df2.groupby(['gender'])['time_in_hospital'].mean().sort_values(ascending=False)
# Out:
# gender
# Female             4.479832
# Male               4.303504
# Unknown/Invalid    1.000000
# Name: time_in_hospital, dtype: float64

# %%
#To visualize the result of the above operation
color=['red','blue','lightblue']

df2.groupby(['gender'])['time_in_hospital'].mean().sort_values(ascending=False).plot(kind='bar',color=color)
plt.title('Average time in days spent in hospital due to diabetes by gender')
# Out:
# Text(0.5, 1.0, 'Average time in days spent in hospital due to diabetes by gender')

# %%
#To calculate, applying the groupby function, the average time, in days, spent by a patient at the hospital, per age
df2.groupby(['age'])['time_in_hospital'].mean().sort_values(ascending=False)
# Out:
# age
# [80-90)     4.804345
# [90-100)    4.744860
# [70-80)     4.595469
# [60-70)     4.387166
# [50-60)     4.128973
# [40-50)     4.046064
# [30-40)     3.802920
# [20-30)     3.568591
# [10-20)     3.208211
# [0-10)      2.550000
# Name: time_in_hospital, dtype: float64

# %%
#To visualize the result of the above operation
color=['orange','blue']

df2.groupby(['age'])['time_in_hospital'].mean().sort_values(ascending=False).plot(kind='bar',figsize=(10,6),color=color)
plt.title('Average time in days spent in hospital due to diabetes by age')
# Out:
# Text(0.5, 1.0, 'Average time in days spent in hospital due to diabetes by age')

# %%
#To calculate and compare the number of hospitalized patients who received or did not receive antidiabetic medications, by race
df2.groupby(['diabetesMed','race'])['encounter_id'].count().sort_values(ascending=False)
# Out:
# diabetesMed  race
# Yes          Caucasian          58450
# No           Caucasian          17649
# Yes          AfricanAmerican    14798
# No           AfricanAmerican     4412
# Yes          Hispanic            1551
#              Other               1218
# No           Hispanic             486
# Yes          Asian                475
# No           Other                288
#              Asian                166
# Name: encounter_id, dtype: int64

# %%
#To visualize the result of the above operation
color=['blue']

df2.groupby(['diabetesMed','race'])['encounter_id'].count().sort_values(ascending=False).plot(kind='barh',figsize=(8,6),color=color)
plt.title('hospitalized patients who received or did not receive antidiabetic medications, by race')
# Out:
# Text(0.5, 1.0, 'hospitalized patients who received or did not receive antidiabetic medications, by race')

# %%
#To calculate and compare the number of hospitalized patients who received or did not receive antidiabetic medications, by gender
df2.groupby(['diabetesMed','gender'])['encounter_id'].count().sort_values(ascending=False)
# Out:
# diabetesMed  gender
# Yes          Female             40867
#              Male               35624
# No           Female             12708
#              Male               10293
# Yes          Unknown/Invalid        1
# Name: encounter_id, dtype: int64

# %%
#To visualize the above operation
color=['purple','orange']

df2.groupby(['diabetesMed','gender'])['encounter_id'].count().sort_values(ascending=False).plot(kind='barh',figsize=(8,4),color=color)
plt.title('hospitalized patients who received or did not receive antidiabetic medications, by gender')
# Out:
# Text(0.5, 1.0, 'hospitalized patients who received or did not receive antidiabetic medications, by gender')

# %%
#To calculate and compare the number of hospitalized patients who received or did not receive antidiabetic medications, by age
df2.groupby(['diabetesMed','age'])['encounter_id'].count().sort_values(ascending=False)
# Out:
# diabetesMed  age
# Yes          [70-80)     19675
#              [60-70)     17212
#              [50-60)     13115
#              [80-90)     12582
#              [40-50)      7224
# No           [70-80)      5794
#              [60-70)      4776
#              [80-90)      4218
#              [50-60)      3780
# Yes          [30-40)      2789
# No           [40-50)      2241
# Yes          [90-100)     1890
#              [20-30)      1281
# No           [30-40)       910
#              [90-100)      834
# Yes          [10-20)       591
# No           [20-30)       330
# Yes          [0-10)        133
# No           [10-20)        91
#              [0-10)         27
# Name: encounter_id, dtype: int64

# %%
#To visualize the above result
color=['red']

df2.groupby(['diabetesMed','age'])['encounter_id'].count().sort_values(ascending=False).plot(kind='barh',figsize=(8,8),color=color)
plt.title('hospitalized patients who received or did not receive antidiabetic medications, by age')
# Out:
# Text(0.5, 1.0, 'hospitalized patients who received or did not receive antidiabetic medications, by age')

# %% [markdown]
# **Conclusion**
# The original dataset contains 101766 rows and 50 columns. After a cleaning process, the number of rows was reduced to 99493. Additionally, for the purposes of analysis, a subset was created with the following columns: encounter_id, patient_nbr, race, gender, age, time_in_hospital, and diabetesMed .
# The analysis of the data made it possible to arrive at the following conclusions:
# -Patients of so-called Caucasian race are by far the most numerous to be hospitalized due to diabetes, 76,099 cases or 76.48%. In second place come African Americans with 19,210 cases or 19.31%. Asians are the least present with 641 cases or 0.64%.
# -In relation to gender, female hospitalizations, 53,575 or 53.84%, exceed those of men who show 45,917 cases or 46.15%.
# -In relation to age, it is the 70-80 year olds who come out on top with 25,469 cases or 25.60%. 0-10 year olds are the least numerous, 160 cases or 0.16%.
# -A second measure was analyzed: the time spent in the hospital by patients. In this case, it is African Americans who come first with an average stay of 4.5 days per hospitalization. Last place is occupied by Asians with an average of 3.99 days. On the other hand, women with an average stay of 4.47 days exceed men who have an average of 4.30 days. In terms of age, it is those aged 80-90 who dominate the ranking with an average stay of 4.80 days.
# -The last parameter to be analyzed is whether or not antidiabetic medications were taken during hospitalization. Caucasians come out on top both for taking medication, 58,450 cases, and for not taking it, 17,649 cases. In relation to gender, women dominate both for taking, 40,867 cases or 41.07%, and for not taking medications, 12,708 cases or 12.77%. From the point of view of age, 70-80 year olds occupy the first class of the ranking with 19,675 cases or 19.77%, followed by 60-70 year olds with 17,212 cases or 17.30%.
