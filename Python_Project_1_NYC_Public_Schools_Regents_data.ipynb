# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#To download the dataset
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %% [markdown]
# **An exploration of NYC public schools**
#
# **The Task**
#
# -the goal of this project is to analyze student test performance
#
# -pick any school in this dataset as an initial comparison point
#
# -pick a feature/measure/score
#
# -compare above school to schools in the entire dataset, schools in a
# particular borough, or schools in a particular district - you only need
# to do one additional comparison point (but you’re welcome to do
# more comparisons if you feel compelled to do so)
#
# -the analysis should include some descriptive statistics
#
# -the analysis should include one cleaning task (or more)
#
# -the analysis should include one visualization (or more)

# %%
#To understand the dataset
df.head(10)
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
# 5     01M140          P.S. 140 Nathan Straus          K-8
# 6     01M140          P.S. 140 Nathan Straus          K-8
# 7     01M140          P.S. 140 Nathan Straus          K-8
# 8     01M184            P.S. 184m Shuang Wen          K-8
# 9     01M184            P.S. 184m Shuang Wen          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          s                       s
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# ...

# %%
#To understand the dataset
df.tail()
# Out:
#        School DBN           School Name School Level  \
# 212326     84X717  Icahn Charter School          K-8
# 212327     84X717  Icahn Charter School          K-8
# 212328     84X717  Icahn Charter School          K-8
# 212329     84X717  Icahn Charter School          K-8
# 212330     84X717  Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 212326           Living Environment  2016             8          s
# 212327           Living Environment  2016             5          s
# 212328           Living Environment  2017             6          s
# 212329           Living Environment  2017             4          s
# 212330  U.S. History and Government  2015             1          s
#
#        Number Scoring Below 65 Percent Scoring Below 65  \
# 212326                       s                        s
# 212327                       s                        s
# 212328                       s                        s
# ...

# %%
#To obtain the summary statistics of the dataset
df.describe()
# Out:
#                 Year   Total Tested
# count  212331.000000  212331.000000
# mean     2015.956069      49.364200
# std         0.799726      93.023576
# min      2015.000000       1.000000
# 25%      2015.000000       5.000000
# 50%      2016.000000      20.000000
# 75%      2017.000000      57.000000
# max      2017.000000    1729.000000

# %%
#To verify the existence or not of missing data
df.count()
# Out:
# School DBN                     212331
# School Name                    212331
# School Level                   212331
# Regents Exam                   212321
# Year                           212331
# Total Tested                   212331
# Mean Score                     212331
# Number Scoring Below 65        212331
# Percent Scoring Below 65       212331
# Number Scoring 65 or Above     212331
# Percent Scoring 65 or Above    212331
# Number Scoring 80 or Above     212331
# Percent Scoring 80 or Above    212331
# Number Scoring CR              212331
# Percent Scoring CR             212331
# dtype: int64

# %%
#To confirm the number of rows and columns in the dataset
df.shape
# Out:
# (212331, 15)

# %%
#To verify the data types, (values in 13 columns are strings designated as 'object'in the report below)
print(df.dtypes)
# Out:
# School DBN                     object
# School Name                    object
# School Level                   object
# Regents Exam                   object
# Year                            int64
# Total Tested                    int64
# Mean Score                     object
# Number Scoring Below 65        object
# Percent Scoring Below 65       object
# Number Scoring 65 or Above     object
# Percent Scoring 65 or Above    object
# Number Scoring 80 or Above     object
# Percent Scoring 80 or Above    object
# Number Scoring CR              object
# Percent Scoring CR             object
# dtype: object

# %%
#To create a subset of the dataset for the requested task (analysis). We will name it df2. (filtering columns)
df2 = df[['School DBN','School Name','School Level','Regents Exam','Year','Total Tested','Mean Score']]

# %%
#To view and understand df2
df2.head()
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested Mean Score
# 0  Common Core Algebra  2017             4          s
# 1   Living Environment  2015            16       77.9
# 2   Living Environment  2016             9         74
# 3  Common Core Algebra  2016             3          s
# 4  Common Core Algebra  2017             2          s

# %%
#Processing the data in the Mean Score column by replacing the string 's' value by its numeric equivalent '75' (Rf. NYC, DOE: High School Academic Policy Guide)
df2["Mean Score"]=df2["Mean Score"].replace("s","75")
NB.
When we filter rows in the dataset by applying the code  df2[df2['Mean Score']=='s'] , we obtain a count of 75222 rows (35.42% of total rows in the dataset), which is very important. It's a choice of the dataset owner to have 's' as values in the dataset (Rf. dataset dictionary). But, instead of dropping all these values that could affect the relevance  of the analysis,  we have opted, regarding the "Mean Score" column, to inpute "75" as the numeric value of "s" as indicated in the E-U scale, in accordance with  the " NYC, DOE: High School Academic Policy Guide"
# Out:
# <ipython-input-11-678a81807885>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2["Mean Score"]=df2["Mean Score"].replace("s","75")

# %%
#To verify that 's' has been effectively replaced by '75', (but the data type is still object that means string)
df2['Mean Score']
# Out:
# 0           75
# 1         77.9
# 2           74
# 3           75
# 4           75
#           ...
# 212326      75
# 212327      75
# 212328      75
# 212329      75
# 212330      75
# Name: Mean Score, Length: 212331, dtype: object

# %%
#To get a new view of df2
df2.head()
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
#
#           Regents Exam  Year  Total Tested Mean Score
# 0  Common Core Algebra  2017             4         75
# 1   Living Environment  2015            16       77.9
# 2   Living Environment  2016             9         74
# 3  Common Core Algebra  2016             3         75
# 4  Common Core Algebra  2017             2         75

# %%
#To get a new view of df2
df2.tail()
# Out:
#        School DBN           School Name School Level  \
# 212326     84X717  Icahn Charter School          K-8
# 212327     84X717  Icahn Charter School          K-8
# 212328     84X717  Icahn Charter School          K-8
# 212329     84X717  Icahn Charter School          K-8
# 212330     84X717  Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score
# 212326           Living Environment  2016             8         75
# 212327           Living Environment  2016             5         75
# 212328           Living Environment  2017             6         75
# 212329           Living Environment  2017             4         75
# 212330  U.S. History and Government  2015             1         75

# %%
#Processing the data in the subset  df2 by converting the strings of column 'Mean Score' to floats
df2['Mean Score']=df2['Mean Score'].astype(float)
# Out:
# <ipython-input-15-158aca299c2b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Mean Score']=df2['Mean Score'].astype(float)

# %%
#To confirm that the conversion has been done, (the data type is now float64 in the Mean Score column)
df2['Mean Score']
# Out:
# 0         75.0
# 1         77.9
# 2         74.0
# 3         75.0
# 4         75.0
#           ...
# 212326    75.0
# 212327    75.0
# 212328    75.0
# 212329    75.0
# 212330    75.0
# Name: Mean Score, Length: 212331, dtype: float64

# %%
#To get the summary statistics for df2
df2.describe()
# Out:
#                 Year   Total Tested     Mean Score
# count  212331.000000  212331.000000  212331.000000
# mean     2015.956069      49.364200      69.187741
# std         0.799726      93.023576      10.041178
# min      2015.000000       1.000000      15.000000
# 25%      2015.000000       5.000000      62.400000
# 50%      2016.000000      20.000000      74.400000
# 75%      2017.000000      57.000000      75.000000
# max      2017.000000    1729.000000      98.700000

# %%
#To obtain the median for df2 (result same as 50%)
df2.median()
# Out:
# <ipython-input-18-96b6afdc328d>:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df2.median()
# Year            2016.0
# Total Tested      20.0
# Mean Score        74.4
# dtype: float64

# %%
#To create a second subset (df3) containing only the data of Jean Nuzzi Intermediate School (DBN = 29Q109) and understand it (filtering rows).
df3 = df2[df2['School DBN']=='29Q109']
df3.head()
# Out:
#       School DBN                     School Name  \
# 15872     29Q109  Jean Nuzzi Intermediate School
# 15873     29Q109  Jean Nuzzi Intermediate School
# 15874     29Q109  Jean Nuzzi Intermediate School
# 15875     29Q109  Jean Nuzzi Intermediate School
# 15876     29Q109  Jean Nuzzi Intermediate School
#
#                           School Level         Regents Exam  Year  \
# 15872  Junior High-Intermediate-Middle  Common Core Algebra  2015
# 15873  Junior High-Intermediate-Middle  Common Core Algebra  2016
# 15874  Junior High-Intermediate-Middle  Common Core Algebra  2017
# 15875  Junior High-Intermediate-Middle   Living Environment  2015
# 15876  Junior High-Intermediate-Middle   Living Environment  2016
#
#        Total Tested  Mean Score
# 15872            60        74.8
# 15873            94        83.8
# 15874            87        85.2
# 15875            73        83.4
# 15876            89        82.4

# %%
#To view and understand df3
df3.tail()
# Out:
#        School DBN                     School Name  \
# 199895     29Q109  Jean Nuzzi Intermediate School
# 199896     29Q109  Jean Nuzzi Intermediate School
# 199897     29Q109  Jean Nuzzi Intermediate School
# 199898     29Q109  Jean Nuzzi Intermediate School
# 199899     29Q109  Jean Nuzzi Intermediate School
#
#                            School Level        Regents Exam  Year  \
# 199895  Junior High-Intermediate-Middle  Living Environment  2017
# 199896  Junior High-Intermediate-Middle  Living Environment  2017
# 199897  Junior High-Intermediate-Middle  Living Environment  2017
# 199898  Junior High-Intermediate-Middle  Living Environment  2017
# 199899  Junior High-Intermediate-Middle  Living Environment  2017
#
#         Total Tested  Mean Score
# 199895            40        80.9
# 199896            17        80.1
# 199897            12        78.4
# 199898             5        75.0
# 199899             1        75.0

# %%
#To confirm the number of rows and columns in df3
df3.shape
# Out:
# (67, 7)

# %%
#To get the  summary statistics of df3 (Jean Nuzzi Intermediate School)
df3.describe()
# Out:
#               Year  Total Tested  Mean Score
# count    67.000000     67.000000   67.000000
# mean   2016.014925     35.671642   80.144776
# std       0.807025     29.053967    4.258442
# min    2015.000000      1.000000   72.600000
# 25%    2015.000000      9.500000   75.000000
# 50%    2016.000000     32.000000   81.500000
# 75%    2017.000000     57.500000   83.650000
# max    2017.000000     94.000000   87.900000

# %%
#To obtain the median for df3 (result same as 50%)
df3.median()
# Out:
# <ipython-input-23-d2c830c2792c>:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df3.median()
# Year            2016.0
# Total Tested      32.0
# Mean Score        81.5
# dtype: float64

# %%
#To create a third subset (df4) containing the data for the schools of District 29 in Queens (filtering rows)
df4 = df2[df2['School DBN'].str.contains('29Q')]

# %%
#To view and understand df4
df4.head()
# Out:
#       School DBN                   School Name  \
# 15864     29Q059  I.S. 059 Springfield Gardens
# 15865     29Q059  I.S. 059 Springfield Gardens
# 15866     29Q059  I.S. 059 Springfield Gardens
# 15867     29Q059  I.S. 059 Springfield Gardens
# 15868     29Q059  I.S. 059 Springfield Gardens
#
#                           School Level         Regents Exam  Year  \
# 15864  Junior High-Intermediate-Middle  Common Core Algebra  2015
# 15865  Junior High-Intermediate-Middle  Common Core Algebra  2016
# 15866  Junior High-Intermediate-Middle  Common Core Algebra  2017
# 15867  Junior High-Intermediate-Middle   Living Environment  2015
# 15868  Junior High-Intermediate-Middle   Living Environment  2016
#
#        Total Tested  Mean Score
# 15864            29        68.9
# 15865            27        78.9
# 15866            37        76.6
# 15867            17        81.1
# 15868            26        75.9

# %%
#To view and understand df4
df4.tail()
# Out:
#        School DBN                           School Name School Level  \
# 201574     29Q498  Humanities & Arts Magnet High School  High school
# 201575     29Q498  Humanities & Arts Magnet High School  High school
# 201576     29Q498  Humanities & Arts Magnet High School  High school
# 201577     29Q498  Humanities & Arts Magnet High School  High school
# 201578     29Q498  Humanities & Arts Magnet High School  High school
#
#                        Regents Exam  Year  Total Tested  Mean Score
# 201574  U.S. History and Government  2017             3        75.0
# 201575  U.S. History and Government  2017           105        66.5
# 201576  U.S. History and Government  2017            12        73.8
# 201577  U.S. History and Government  2017             3        75.0
# 201578  U.S. History and Government  2017             2        75.0

# %%
#To confirm the number of rows and columns in df4
df4.shape
# Out:
# (4936, 7)

# %%
#To obtain the summary statistics of df4
df4.describe()
# Out:
#               Year  Total Tested   Mean Score
# count  4936.000000   4936.000000  4936.000000
# mean   2015.938209     35.140802    68.126600
# std       0.797940     47.683946     9.333206
# min    2015.000000      1.000000    34.100000
# 25%    2015.000000      3.000000    61.400000
# 50%    2016.000000     12.000000    73.900000
# 75%    2017.000000     51.250000    75.000000
# max    2017.000000    305.000000    90.500000

# %%
#To obtain the median of df4 (same as 50%)
df4.median()
# Out:
# <ipython-input-29-ef8429d9a1ef>:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df4.median()
# Year            2016.0
# Total Tested      12.0
# Mean Score        73.9
# dtype: float64

# %%
#To create a fourth subset to store the data regarding all  schools in Queens Borough
df5 = df2[df2['School DBN'].str.contains('Q')]

# %%
#To view and understand df5
df5.head()
# Out:
#       School DBN                                      School Name  \
# 13095     24Q457                        H.S. Arts & Business Yabc
# 13364     24Q005  I.S. 5 - The Walter Crowley Intermediate School
# 13365     24Q005  I.S. 5 - The Walter Crowley Intermediate School
# 13366     24Q005  I.S. 5 - The Walter Crowley Intermediate School
# 13367     24Q005  I.S. 5 - The Walter Crowley Intermediate School
#
#                           School Level         Regents Exam  Year  \
# 13095                      High school              English  2016
# 13364  Junior High-Intermediate-Middle  Common Core Algebra  2015
# 13365  Junior High-Intermediate-Middle  Common Core Algebra  2016
# 13366  Junior High-Intermediate-Middle  Common Core Algebra  2017
# 13367  Junior High-Intermediate-Middle  Common Core English  2017
#
#        Total Tested  Mean Score
# 13095            20        55.5
# 13364            89        82.9
# 13365            90        86.5
# 13366            92        89.7
# ...

# %%
#To view and understand df5
df5.tail()
# Out:
#        School DBN                            School Name School Level  \
# 210614     84Q706  Our World Neighborhood Charter School          K-8
# 210615     84Q706  Our World Neighborhood Charter School          K-8
# 210616     84Q706  Our World Neighborhood Charter School          K-8
# 210617     84Q706  Our World Neighborhood Charter School          K-8
# 210618     84Q706  Our World Neighborhood Charter School          K-8
#
#               Regents Exam  Year  Total Tested  Mean Score
# 210614  Living Environment  2017             4        75.0
# 210615  Living Environment  2017             2        75.0
# 210616  Living Environment  2017             8        88.1
# 210617  Living Environment  2017             1        75.0
# 210618  Living Environment  2017             4        75.0

# %%
df5.shape
# Out:
# (39633, 7)

# %%
df5.count()
# Out:
# School DBN      39633
# School Name     39633
# School Level    39633
# Regents Exam    39633
# Year            39633
# Total Tested    39633
# Mean Score      39633
# dtype: int64

# %%
#To obtain the summary statistics of df5
df5.describe()
# Out:
#                Year  Total Tested    Mean Score
# count  39633.000000  39633.000000  39633.000000
# mean    2015.974869     71.953170     70.766260
# std        0.800292    125.149988      9.826452
# min     2015.000000      1.000000     24.300000
# 25%     2015.000000      7.000000     64.600000
# 50%     2016.000000     27.000000     75.000000
# 75%     2017.000000     81.000000     75.000000
# max     2017.000000   1384.000000     97.600000

# %%
#To obtain the median of df5 (same as 50%)
df5.median()
# Out:
# <ipython-input-36-5ee882621a4b>:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df5.median()
# Year            2016.0
# Total Tested      27.0
# Mean Score        75.0
# dtype: float64

# %%
#To obtain the mean score per year  for all Queens Borough schools
df5.groupby(['Year'])['Mean Score'].mean().sort_values(ascending=False)
# Out:
# Year
# 2017    71.191725
# 2016    70.762369
# 2015    70.377087
# Name: Mean Score, dtype: float64

# %%
#To Visualize the mean score  per year for all Queens Borough schools
df5.groupby(['Year'])['Mean Score'].mean().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='Year'>

# %%
#To obtain, over the 3 years, the average number of  students tested in Regents Exam per school in Distrct 29, Queens.
df4.groupby(['School DBN'])['Total Tested'].mean().sort_values(ascending=False)
# Out:
# School DBN
# 29Q238    54.010989
# 29Q272    50.000000
# 29Q498    46.629902
# 29Q283    41.324885
# 29Q265    39.450128
# 29Q259    38.059126
# 29Q492    38.000000
# 29Q248    37.770115
# 29Q109    35.671642
# 29Q326    35.648585
# 29Q327    35.513308
# 29Q313    33.902954
# 29Q138    29.090909
# 29Q270    18.666667
# 29Q355    18.285714
# 29Q059    18.285714
# 29Q243    18.050000
# 29Q208    13.898305
# 29Q192    12.933333
# 29Q356    11.621622
# 29Q496    10.706522
# 29Q494     9.687500
# 29Q295     9.487179
# 29Q289     8.906250
# 29Q268     7.222222
# 29Q147     1.000000
# Name: Total Tested, dtype: float64

# %%
# To visualize the average number of students tested in Regents Exam per school in Distrct 29, Queens.
df4.groupby(['School DBN'])['Total Tested'].mean().sort_values(ascending=False).plot(kind='bar')
# Out:
# <Axes: xlabel='School DBN'>

# %%
df4.groupby(['School DBN'])['Mean Score'].mean().sort_values(ascending=False)
# Out:
# School DBN
# 29Q109    80.144776
# 29Q295    78.356410
# 29Q208    77.108475
# 29Q270    77.073333
# 29Q059    76.220000
# 29Q356    75.832432
# 29Q238    75.259341
# 29Q147    75.000000
# 29Q268    74.683333
# 29Q192    74.385333
# 29Q289    74.118750
# 29Q243    73.794000
# 29Q494    70.027083
# 29Q283    69.851152
# 29Q496    69.632609
# 29Q265    68.937340
# 29Q355    68.902857
# 29Q327    67.425095
# 29Q313    67.386498
# 29Q259    67.353470
# 29Q272    65.736342
# 29Q498    65.671814
# 29Q492    65.645783
# 29Q326    65.219104
# 29Q138    65.093506
# 29Q248    64.742759
# Name: Mean Score, dtype: float64

# %%
df4.groupby(['School DBN'])['Mean Score'].mean().sort_values(ascending=False).plot(kind='bar').plot(kind='bar')
# Out:
# []

# %% [markdown]
# **Performance comparison table based on the summary statistics (describe)obtained from the Mean Score column for: **
#
#       All NYC Schools     Queens Borough    District 29       Jean Nuzzi
#                                 Schools         Schools    Intermediate School
#
# Mean           69.18            70.76             68.12           80.14
#
# Median         74.4             75.0              73.9            81.5
#
# Min            15.0             24.3              34.1            72.6
#
# Max            98.7             97.6              90.5            87.9
#
#
# **Conclusion**
# The above table is based on the figures  obtained from the Mean Score column for: All NYC Schools, Queens Borough Schools, District 29 Schools, and Jean Nuzzi Intermediate School(29Q109) . The data shows that Jean Nuzzi Intermediate School has an average Mean Score (80.14), a Median (81.5) and a Min (72.6) that are larger than  the figures associated to All NYC Schools (69.18, 74.4, 15.0), Queens Borough Schools (70.76, 75.0, 24.3), and District 29 Schools (68.12, 73.9, 34.1).  The difference in the Min value is particularly significant. While Jean Nuzzi School has a score of 72.6, the values related to All NYC Schools,  Queens Borough Schools, and District 29 Schools are respectively 15.0, 24.3, and 34.1. Nevertheless, regarding the Max value, Jean Nuzzi School with a score of 87.9 is left in 4th position behind All NYC Schools (98.7), Queens Borough Schools (97.6), and District 29 Schools (90.5).
#
# Inside District 29, the largest mean score (80.14) is detained by Jean Nuzzi Intermediate School while Queens Preparatory Academy (DBN:29Q247) has the lowest mean score(64.74). On the other hand, in the same District, the average number of students tested in Regents Exam vary from 54.01 (Score of Susan B. Anthony Academy, DBN:29Q238) to 1 (score of Mc Nair Elemeentary School, DBN:29Q147)
#
# Regarding the Mean Score per year for all Queens Borough schools, the following scores are obtained: 71.19 for 2017, 70.76 for 2016, and 70.37 for 2015.
